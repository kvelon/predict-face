# %%
import numpy as np
import pickle
import torch
import pandas as pd
from pathlib import Path
import json
from torchvision import transforms
import matplotlib.pyplot as plt

from utils import *

# %%
################################
## CHANGE BEFORE CONITNUING ####
################################
data_path = Path("../data") / "samples_13_july"

# %% [markdown]
# ## Claim dataframe

# %%
file = open(data_path / "claims.pkl", 'rb')
claims = pickle.load(file)
file.close()

# %%
claims['height'].value_counts()
# Out:
# 852    53
# 854     7
# Name: height, dtype: int64

# %%
claims['width'].unique()
# Out:
# array([480])

# %% [markdown]
# ## Cropping to 852 x 480

# %%
npz_obj = np.load("../data/samples_13_july/videos/001edf2e5c478a319cf189c1a9023a58622c76ec1a283265112668161801vi07.npz")

# %%
vid = npz_obj['data']
# Out:
# (10, 852, 480, 3)

# %%
plt.imshow(npz_obj['data'][0])

# %% [markdown]
# ## Full numpy array

# %%
arr = np.load(data_path / "combined.npy")
arr.shape
# Out:
# (58, 10, 852, 480, 3)

# %%
f, h, w, c = arr[0].shape

# %%
torch.zeros(h, w, c).shape
# Out:
# torch.Size([852, 480, 3])

# %%
lst[3:5]
# Out:
# [3, 4]
